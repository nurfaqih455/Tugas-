# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\Acer\JST_INFORMATIKA6\image\kie.JPG")
#img = cv2.imread("image/kie.JPG", cv2.IMREAD_UNCHANGED)

# %%
print('Original Image', img.shape)

# %%
scale_percent = 60
width = int(img.shape[1] * scale_percent / 500)
height = int(img.shape[0] * scale_percent / 500)
dim = (width, height)

# %% [markdown]
# im1 = im.crop((left, top, right, bottom))
# newsize = (200, 200)
# im1 = im1.resize(newsize)

# %%
resized = cv2.resize(img, (400,500))

# %%
cv2.imwrite(r"C:\Users\Acer\JST_INFORMATIKA6\hasil\kie.JPG",resized)

# %%
img = cv2.imread(r"C:\Users\Acer\JST_INFORMATIKA6\hasil\kie.JPG")

# %%
from matplotlib import pyplot as plt

# %%
imgplot = plt.imshow(img)
